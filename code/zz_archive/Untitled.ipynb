# %%
import streamstats as ss
import pandas as pd

# %%
pnwNP = pd.read_csv("../data/pnwNP_Info.csv")

# %%
pnwNP
# Out:
#      X  Unnamed..0      gage  counts  \
# 0    0           0  12115700      29
# 1    1           1  12116500       1
# 2    2           2  12143700       1
# 3    3           3  12323770       3
# 4    4           4  12465000       2
# 5    5           5  12513000      63
# 6    6           6  13055340      31
# 7    7           7  13058000       5
# 8    8           8  13068500      16
# 9    9           9  13068501      15
# 10  10          10  13082500       1
# 11  11          11  13112000      24
# 12  12          12  13132500      18
# 13  13          13  13132520      21
# 14  14          14  13132535      26
# 15  15          15  13142500       2
# 16  16          16  13152500      29
# 17  17          17  13159800       5
# 18  18          18  13174500       6
# 19  19          19  13215000      34
# 20  20          20  13217500      24
# 21  21          21  13236500       1
# 22  22          22  13297350       7
# 23  23          23  14015000      36
# ...

# %%
lat = pnwNP['dec_lat_va_y'][0]
long = pnwNP['dec_long_va_y'][0]

# %%
tt = ss.watershed.Watershed(lat,long)

# %%
tt.huc
# Out:
# '1711'

# %%
tt.data
# Out:
# {'workspaceID': 'WA20230629210925534000',
#  'featurecollection': [{'name': 'globalwatershedpoint',
#    'feature': {'type': 'FeatureCollection',
#     'crs': {'type': 'ESPG', 'properties': {'code': 4326}},
#     'features': [{'properties': {'FID': 0,
#        'OBJECTID': 1,
#        'Mesure': 0,
#        'DESCRIPT': 'P1711',
#        'HUCID': '1711',
#        'DRAINID': 2,
#        'Longitude': 0,
#        'HYDROID': 1,
#        'Measure': 0,
#        'Latitude': 0,
#        'ReachCode': ' ',
#        'NAME': 'ags101'},
#       'type': 'Feature',
#       'bbox': [-121.69297794404375, 47.366201616600634],
#       'geometry': {'type': 'Point',
#        'coordinates': [-121.69297794404375, 47.366201616600634]}}]}},
#   {'name': 'globalwatershed',
#    'feature': {'type': 'FeatureCollection',
#     'crs': {'type': 'ESPG', 'properties': {'code': 4326}},
#     'features': [{'properties': {'ELEVMIN': 0,
#        'SLPPCT': 0,
#        'NFSL30': 0,
#        'HYDROID': 2,
# ...
