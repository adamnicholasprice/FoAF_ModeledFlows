# %%
import pandas as pd
import 

## Color pallete
# from EE https://mycolor.space/?hex=%23E98F83&sub=1
# https://mycolor.space/?hex=%2396B06A&sub=1

## 2 colors for NP/NP

# NP = #89B448
# P = #EF8F57

## 6 colors for hydrolandscape
pal = {'very_wet': '#728C48',
       'wet': '#96B06A',
       'moist': '#C6BD6C',
       'dry': '#FFCD93',
       'semi_arid': '#EC975F' ,
       'arid': '#B0632F'}

pal = {'V': '#728C48',
       'W': '#96B06A',
       'M': '#C6BD6C',
       'D': '#FFCD93',
       'S': '#EC975F' ,
       'A': '#B0632F'}



## Data maps
#2 colors for streamgage (prob 1 and grey)

#5 colors for statistical model map

#2 colors for non-continuous gages,flowper


### 4 colors for KGE and decomp
palette = ["#96B06A","#C4A49E","#B3A5C8","#98D3F5"] ##currently KGE decomposition

#96B06A
#FFCD93
#EC975F
#B0632F

### 5/6 colors for model comparision


NWIS = #95B0B4
NWM3 = #96B06A
NWM2.1 = #C6BD6C
NWM2.0 = #F8C678
VIC = #FFCD93
PRMS = #EC975F
