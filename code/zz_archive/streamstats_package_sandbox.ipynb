# %%
import streamstats as ss
import pandas as pd

# %%
pnwNP = pd.read_csv("../data/pnwNP_StatsLocationsSSwNames.csv")

# %%
pnwNP
# Out:
#      Unnamed: 0          site_no  \
# 0             0         10361700
# 1             1         10366000
# 2             2         10378500
# 3             3         10387500
# 4             4         10389500
# ..          ...              ...
# 613         613         14375400
# 614         614  433247110491701
# 615         615  452755122234100
# 616         616  452807122215001
# 617         617  480608115242901
#
#                                             station_nm  Unnamed: 0.1  \
# 0                            BADGER CK TRIB NR VYA, NV             0
# 1                     TWENTYMILE CREEK NEAR ADEL,OREG.             1
# 2                         HONEY CREEK NEAR PLUSH,OREG.             2
# 3               SUMMER LAKE CANAL NR SUMMER LAKE,OREG.             3
# 4          SILVER LK IRRIG DIST CA NR SILVER LAKE, OR.             4
# ..                                                 ...           ...
# 613                        ELK CREEK NEAR OBRIEN,OREG.           613
# ...

# %%
i = 63
lat = pnwNP['dec_lat'][i]
long = pnwNP['dec_long'][i]

# %%
tt = ss.watershed.Watershed(lat,long)
