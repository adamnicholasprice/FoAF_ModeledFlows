# %%
import pandas as pd
import requests
import json
import numpy as np
import dataretrieval as nwis

# %%
def getAllStreamStats(i):
    ## Define gage location
#     y_loc = dat["dec_lat_va"][i]
#     x_loc = dat["dec_long_va"][i]
    
    y_loc = np.round(dat["dec_lat_va"][i],2)
    x_loc = np.round(dat["dec_long_va"][i],2)
    state = 'OR'
    gage = dat["gage"][i]
    
    
    ## Define Streamstats API URLS
    # Service URLS
    StreamStatsServiceURLS = {
        'watershed': 'https://streamstats.usgs.gov/streamstatsservices/watershed.geojson',
        'basinCharacteristics': 'https://streamstats.usgs.gov/streamstatsservices/parameters.json',
        'gage': 'https://streamstats.usgs.gov/gagestatsservices/stations'
        }
    NSSServiceURlS = {
        'regressionRegions': 'https://streamstats.usgs.gov/nssservices/regressionregions/bylocation',
        'scenarios': 'https://streamstats.usgs.gov/nssservices/scenarios',
        'computeFlowStats': 'https://streamstats.usgs.gov/nssservices/scenarios/Estimate'
    }

    # Declare cookies for use of consistent StreamStats servers
    global cookies 
    
    # Step 1 - Get the watershed
    print('Step 1 - Get the watershed')
    watershedURLParams = {
        'rcode': state, 
        'xlocation': x_loc, 
        'ylocation': y_loc,
        'crs': 4326,
    #     'crs': 4269,
    }
    delineatedBasin = None
    while delineatedBasin is None: # Sometimes the watershed endpoint returns with no geometry - this loop is written to keep trying until a geometry is returned
        print('Delineating basin...')
        basinDelineationResponse = requests.get(url = StreamStatsServiceURLS['watershed'], params = watershedURLParams)
        if basinDelineationResponse.status_code == 200:
            cookies = basinDelineationResponse.cookies
            try:
                delineatedBasin = json.loads(basinDelineationResponse.content.decode('utf-8'))["featurecollection"][1]["feature"]["features"][0]["geometry"] # this will be used in step 2
                workspaceID = json.loads(basinDelineationResponse.content.decode('utf-8'))["workspaceID"] # this will be used in step 4
            except:
                print("No geometry returned. Retrying...")
                pass
        else:
            print("Error. Retrying...")
            pass

    # Step 2 - Get the Regression Regions associated with the watershed
    print('Step 2 - Get the Regression Regions associated with the watershed')
    regressionRegionPOSTBody = delineatedBasin # from step 1

    regressionRegions = None
    while regressionRegions == None:
        regressionRegionsResponse = requests.post(url = NSSServiceURlS['regressionRegions'], json=regressionRegionPOSTBody)
        if regressionRegionsResponse.status_code == 200:
            regressionRegions = json.loads(regressionRegionsResponse.content.decode('utf-8'))
            regressionRegionCodes = [ sub['code'] for sub in regressionRegions ] # this will be used in step 3
        else:
            print("Error.")
            pass

    # Step 3 - Get the Scenarios associated with the Regression Regions
    print('Step 3 - Get the Scenarios associated with the Regression Regions')

    scenarioURLParams = {
        'regions': state, 
        'statisticgroups': 4, # this can be updated depending on which flow statistics you want to calculate (2 is associated with Peak Flow Statistics) - you can find all statistic groups available for your region at https://streamstats.usgs.gov/docs/nssservices/#/StatisticGroups/GET/StatisticGroups
        'regressionregions': (','.join(regressionRegionCodes)) # from step 2, needs to be comma separated list
    }
    scenarioResponse = requests.get(url = NSSServiceURlS['scenarios'], params=scenarioURLParams)

    parameters = None
    while parameters == None:
        if scenarioResponse.status_code == 200:
            scenarios = json.loads(scenarioResponse.content.decode('utf-8'))[0] # this will be used in step 5
            parameters = json.loads(scenarioResponse.content.decode('utf-8'))[0]["regressionRegions"][0]["parameters"]
            parameterCodes = [ sub['code'] for sub in parameters ] # this will be used in step 4
        else:
            print("Error.")
            pass

    # Step 4 - Compute the basin characteristics
    print('Step 4 - Compute the basin characteristics')
    basinCharacteristicsURLParams = {
        'rcode': state, 
        'workspaceID': workspaceID, # from step 1
        'includeparameters': (','.join(parameterCodes)) # from step 3
    }

    basinCharacteristics = None
    while basinCharacteristics is None:
        basinCharacteristicsResponse = requests.get(url = StreamStatsServiceURLS['basinCharacteristics'], params=basinCharacteristicsURLParams, cookies=cookies)
        if basinCharacteristicsResponse.status_code == 200:
            basinCharacteristics = json.loads(basinCharacteristicsResponse.content.decode('utf-8')) # this will be used in step 5
        else:
            print("Error.")
            pass

    # Step 5 - Compute Flow Statistics
    print('Step 5 - Compute Flow Statistics')
    flowStatsURLParams = {
        'regions': state
    }
    flowStatsPOSTBody = [] 
    for counter, x in enumerate(scenarios['regressionRegions'][0]['parameters']): # from step 3 & step 4
        for p in basinCharacteristics['parameters']:
            if x['code'].lower() == p['code'].lower():
                scenarios['regressionRegions'][0]['parameters'][counter]['value'] = p['value']
    flowStatsPOSTBody.append(scenarios)

    flowStats = None
    while flowStats == None:
        flowStatsResponse = requests.post(url = NSSServiceURlS['computeFlowStats'], params = flowStatsURLParams, json=flowStatsPOSTBody)
        if flowStatsResponse.status_code == 200:
            flowStats = json.loads(flowStatsResponse.content.decode('utf-8'))
        else:
            print("Error.")
            pass

    out = pd.json_normalize(flowStats,
                             record_path=['regressionRegions',['results']],
                            )[["code","value"]]
    out["gage"] = gage
    return out

# %%
pnwNPall = pd.read_csv("../data/pnwNPall_InfowStats.csv")
siteID = list(pnwNPall['gage'].astype(str))
dat = nwis.get_info(sites = siteID)[0]


dat["state"] = "none"
dat["state"][dat["state_cd"]==16] = "ID"
dat["state"][dat["state_cd"]==41] = "OR"
dat["state"][dat["state_cd"]==53] = "WA"

st = ["ID",'WA','OR']
dat = dat[dat["state"].isin(st)].reset_index(drop=True)
dat = dat[["site_no","dec_lat_va","dec_long_va",'state','station_nm']]
dat.columns = ["gage","lat","long",'state','name']
dat['gage']  =dat['gage'].astype(int)
dat["lat"] = round(dat["lat"],3)
dat["long"] = round(dat["long"],3)
# Out:
# C:\Users\adamprice\AppData\Local\Temp\ipykernel_43336\1018153480.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dat["state"][dat["state_cd"]==16] = "ID"
# C:\Users\adamprice\AppData\Local\Temp\ipykernel_43336\1018153480.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["state"][dat["state_cd"]==16] = "ID"
# C:\Users\adamprice\AppData\Local\Temp\ipykernel_43336\1018153480.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dat["state"][dat["state_cd"]==41] = "OR"
# C:\Users\adamprice\AppData\Local\Temp\ipykernel_43336\1018153480.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["state"][dat["state_cd"]==41] = "OR"
# C:\Users\adamprice\AppData\Local\Temp\ipykernel_43336\1018153480.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dat["state"][dat["state_cd"]==53] = "WA"
# C:\Users\adamprice\AppData\Local\Temp\ipykernel_43336\1018153480.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["state"][dat["state_cd"]==53] = "WA"
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[99], line 15
#      13 dat = dat[["site_no","dec_lat_va","dec_long_va",'state','station_nm']]
#      14 dat.columns = ["gage","lat","long",'state','name']
# ---> 15 dat['gage']  =dat['gage'].astype(int)
#      16 dat["lat"] = round(dat["lat"],3)
#      17 dat["long"] = round(dat["long"],3)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:6637, in NDFrame.astype(self, dtype, copy, errors)
#    6631     results = [
#    6632         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6633     ]
#    6635 else:
#    6636     # else, only a single dtype is given
# -> 6637     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6638     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6639     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\managers.py:431, in BaseBlockManager.astype(self, dtype, copy, errors)
#     428 elif using_copy_on_write():
#     429     copy = False
# --> 431 return self.apply(
#     432     "astype",
#     433     dtype=dtype,
#     434     copy=copy,
#     435     errors=errors,
#     436     using_cow=using_copy_on_write(),
#     437 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\managers.py:364, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     362         applied = b.apply(f, **kwargs)
#     363     else:
# --> 364         applied = getattr(b, f)(**kwargs)
#     365     result_blocks = extend_blocks(applied, result_blocks)
#     367 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# OverflowError: Python int too large to convert to C long

# %%
dat[dat["gage"]==12115700]
# Out:
# Empty DataFrame
# Columns: [gage, lat, long, state, name]
# Index: []

# %%
# i = 4


# ## Define gage location
# y_loc = dat["lat"][i]
# x_loc = dat["long"][i]
# state = dat["state"][i]
# gage = dat["gage"][i]


y_loc = 44.3790098
x_loc = -123.5956608
state = 'OR'
gage = 14306100



## Define Streamstats API URLS
# Service URLS
StreamStatsServiceURLS = {
    'watershed': 'https://streamstats.usgs.gov/streamstatsservices/watershed.geojson',
    'basinCharacteristics': 'https://streamstats.usgs.gov/streamstatsservices/parameters.json',
    'gage': 'https://streamstats.usgs.gov/gagestatsservices/stations'
    }
NSSServiceURlS = {
    'regressionRegions': 'https://streamstats.usgs.gov/nssservices/regressionregions/bylocation',
    'scenarios': 'https://streamstats.usgs.gov/nssservices/scenarios',
    'computeFlowStats': 'https://streamstats.usgs.gov/nssservices/scenarios/Estimate'
}

# Declare cookies for use of consistent StreamStats servers
global cookies 

# Step 1 - Get the watershed
print('Step 1 - Get the watershed')
watershedURLParams = {
    'rcode': state, 
    'xlocation': x_loc, 
    'ylocation': y_loc,
    'crs': 4326,
#     'crs': 4269,
}
delineatedBasin = None
while delineatedBasin is None: # Sometimes the watershed endpoint returns with no geometry - this loop is written to keep trying until a geometry is returned
    print('Delineating basin...')
    basinDelineationResponse = requests.get(url = StreamStatsServiceURLS['watershed'], params = watershedURLParams)
    if basinDelineationResponse.status_code == 200:
        cookies = basinDelineationResponse.cookies
        try:
            delineatedBasin = json.loads(basinDelineationResponse.content.decode('utf-8'))["featurecollection"][1]["feature"]["features"][0]["geometry"] # this will be used in step 2
            workspaceID = json.loads(basinDelineationResponse.content.decode('utf-8'))["workspaceID"] # this will be used in step 4
        except:
            print("No geometry returned. Retrying...")
    else:
        print("Error. Retrying...")

# Step 2 - Get the Regression Regions associated with the watershed
print('Step 2 - Get the Regression Regions associated with the watershed')
regressionRegionPOSTBody = delineatedBasin # from step 1

regressionRegions = None
while regressionRegions == None:
    regressionRegionsResponse = requests.post(url = NSSServiceURlS['regressionRegions'], json=regressionRegionPOSTBody)
    if regressionRegionsResponse.status_code == 200:
        regressionRegions = json.loads(regressionRegionsResponse.content.decode('utf-8'))
        regressionRegionCodes = [ sub['code'] for sub in regressionRegions ] # this will be used in step 3
    else:
        print("Error.")
        pass

# Step 3 - Get the Scenarios associated with the Regression Regions
print('Step 3 - Get the Scenarios associated with the Regression Regions')

scenarioURLParams = {
    'regions': state, 
    'statisticgroups': 4, # this can be updated depending on which flow statistics you want to calculate (2 is associated with Peak Flow Statistics) - you can find all statistic groups available for your region at https://streamstats.usgs.gov/docs/nssservices/#/StatisticGroups/GET/StatisticGroups
    'regressionregions': (','.join(regressionRegionCodes)) # from step 2, needs to be comma separated list
}
scenarioResponse = requests.get(url = NSSServiceURlS['scenarios'], params=scenarioURLParams)

parameters = None
while parameters == None:
    if scenarioResponse.status_code == 200:
        scenarios = json.loads(scenarioResponse.content.decode('utf-8'))[0] # this will be used in step 5
        parameters = json.loads(scenarioResponse.content.decode('utf-8'))[0]["regressionRegions"][0]["parameters"]
        parameterCodes = [ sub['code'] for sub in parameters ] # this will be used in step 4
    else:
        print("Error.")
        pass

# Step 4 - Compute the basin characteristics
print('Step 4 - Compute the basin characteristics')
basinCharacteristicsURLParams = {
    'rcode': state, 
    'workspaceID': workspaceID, # from step 1
    'includeparameters': (','.join(parameterCodes)) # from step 3
}

basinCharacteristics = None
while basinCharacteristics is None:
    basinCharacteristicsResponse = requests.get(url = StreamStatsServiceURLS['basinCharacteristics'], params=basinCharacteristicsURLParams, cookies=cookies)
    if basinCharacteristicsResponse.status_code == 200:
        basinCharacteristics = json.loads(basinCharacteristicsResponse.content.decode('utf-8')) # this will be used in step 5
    else:
        print("Error.")
        pass

# Step 5 - Compute Flow Statistics
print('Step 5 - Compute Flow Statistics')
flowStatsURLParams = {
    'regions': state
}
flowStatsPOSTBody = [] 
for counter, x in enumerate(scenarios['regressionRegions'][0]['parameters']): # from step 3 & step 4
    for p in basinCharacteristics['parameters']:
        if x['code'].lower() == p['code'].lower():
            scenarios['regressionRegions'][0]['parameters'][counter]['value'] = p['value']
flowStatsPOSTBody.append(scenarios)

flowStats = None
while flowStats == None:
    flowStatsResponse = requests.post(url = NSSServiceURlS['computeFlowStats'], params = flowStatsURLParams, json=flowStatsPOSTBody)
    if flowStatsResponse.status_code == 200:
        flowStats = json.loads(flowStatsResponse.content.decode('utf-8'))
    else:
        print("Error.")
        pass

out = pd.json_normalize(flowStats,
                         record_path=['regressionRegions',['results']],
                        )[["code","value","equation"]]
out["gage"] = gage
# Out:
# Step 1 - Get the watershed
# Delineating basin...
# Step 2 - Get the Regression Regions associated with the watershed
# Step 3 - Get the Scenarios associated with the Regression Regions
# Step 4 - Compute the basin characteristics
# Step 5 - Compute Flow Statistics

# %%
out.equation[1]
# Out:
# 'max(0,1.02287*(10^(-2.7866)*DRNAREA^1.0892*PRECIP^1.6841*WATCAPORR^1.6694))'

# %%
i=4

StreamStatsServiceURLS = {
    'gage': 'https://streamstats.usgs.gov/gagestatsservices/characteristics'
    }


gageURLParams = {
    "stationIDOrCode": 12115700
}


gageResponse = requests.get(url = StreamStatsServiceURLS['gage'], params = gageURLParams)

if gageResponse.status_code == 200:
    cookies = gageResponse.cookies
    try:
        gageStats = pd.DataFrame(json.loads(gageResponse.content.decode('utf-8')))


        varCode = pd.DataFrame(list(gageStats["variableType"]))["code"]
        units = pd.DataFrame(list(gageStats["unitType"]))["name"]

        gS = pd.DataFrame(gageStats[["variableTypeID","value"]]).reset_index(drop=True)
        gS["code"] = varCode
        gS["unit"] = units
        gS =gS.set_index('code')
    except:
        pass
    
else:
    pass

# %%
METRIC = "M7D10Y"
eq = out['equation'][out["code"]==METRIC].values[0].replace("^", "**")
# TT = eval(eq)
eq
# Out:
# '0.000848*DRNAREA**1.17*PRECIP**1.23'

# %%
gageStats
# Out:
#        id  stationID  variableTypeID  unitTypeID  citationID        value  \
# 0   66800       4789              15          36          19     4.460000
# 1   66801       4789              18          36          19     7.490000
# 2   66802       4789              19          36          19     8.140000
# 3   66803       4789               1          35          19     5.068489
# 4   66804       4789             159          18          19    47.416401
# 5   66805       4789             160          18          19  -121.756083
# 6   66806       4789             142          41          19  4350.000000
# 7   66807       4789               6          41          19  3010.000000
# 8   66808       4789               9           1          19    15.630000
# 9   66809       4789               4          37          19    -1.690000
# 10  66810       4789             189          41          19  1610.000000
# 11  66811       4789             128          41          19  2750.000000
# 12  66812       4789             221          40          19     5.110000
# 13  66813       4789              43          11          19    19.200000
# 14  66814       4789             116          11          19    74.000000
# 15  66815       4789              10          11          19    40.600000
# 16  66816       4789              22          11          19     1.640000
# 17  66817       4789              92          40          19     8.900000
# 18  66818       4789             186          47          19     1.010000
# 19  66819       4789              39          36          19   105.010000
# 20  66820       4789             532          11          19    72.510000
# 21  66821       4789             601           1          19     2.070000
#
#    comments                                       variableType  \
# 0      null  {'id': 15, 'name': '24 Hour 2 Year Precipitati...
# 1      null  {'id': 18, 'name': '24 Hour 50 Year Precipitat...
# 2      null  {'id': 19, 'name': '24 Hour 100 Year Precipita...
# 3      null  {'id': 1, 'name': 'Drainage Area', 'code': 'DR...
# 4      null  {'id': 159, 'name': 'Latitude of Basin Centroi...
# 5      null  {'id': 160, 'name': 'Longitude of Basin Centro...
# 6      null  {'id': 142, 'name': 'Maximum Basin Elevation',...
# 7      null  {'id': 6, 'name': 'Mean Basin Elevation', 'cod...
# 8      null  {'id': 9, 'name': 'Basin Shape Factor', 'code'...
# 9      null  {'id': 4, 'name': 'Mean Min January Temperatur...
# 10     null  {'id': 189, 'name': 'Minimum Basin Elevation',...
# 11     null  {'id': 128, 'name': 'Relief', 'code': 'RELIEF'...
# 12     null  {'id': 221, 'name': 'Stream Length Total', 'co...
# 13     null  {'id': 43, 'name': 'N Facing Slopes gt 30pct f...
# 14     null  {'id': 116, 'name': 'Slopes gt 30pct from 30m ...
# 15     null  {'id': 10, 'name': 'Mean Basin Slope from 30m ...
# 16     null  {'id': 22, 'name': 'Percent Impervious NLCD200...
# 17     null  {'id': 92, 'name': 'Basin Length ArcHydro Meth...
# 18     null  {'id': 186, 'name': 'Basin Drainage Density', ...
# 19     null  {'id': 39, 'name': 'Mean Annual Precip PRISM 1...
# 20     null  {'id': 532, 'name': 'Percent_Tree_Canopy_NLCD2...
# 21     null  {'id': 601, 'name': 'SSURGO_Soil_Index', 'code...
#
#                                              unitType  \
# 0   {'id': 36, 'name': 'inches', 'abbreviation': '...
# 1   {'id': 36, 'name': 'inches', 'abbreviation': '...
# 2   {'id': 36, 'name': 'inches', 'abbreviation': '...
# 3   {'id': 35, 'name': 'square miles', 'abbreviati...
# 4   {'id': 18, 'name': 'decimal degrees', 'abbrevi...
# 5   {'id': 18, 'name': 'decimal degrees', 'abbrevi...
# 6   {'id': 41, 'name': 'feet', 'abbreviation': 'ft...
# 7   {'id': 41, 'name': 'feet', 'abbreviation': 'ft...
# 8   {'id': 1, 'name': 'dimensionless', 'abbreviati...
# 9   {'id': 37, 'name': 'degrees F', 'abbreviation'...
# 10  {'id': 41, 'name': 'feet', 'abbreviation': 'ft...
# 11  {'id': 41, 'name': 'feet', 'abbreviation': 'ft...
# 12  {'id': 40, 'name': 'miles', 'abbreviation': 'm...
# 13  {'id': 11, 'name': 'percent', 'abbreviation': ...
# 14  {'id': 11, 'name': 'percent', 'abbreviation': ...
# 15  {'id': 11, 'name': 'percent', 'abbreviation': ...
# 16  {'id': 11, 'name': 'percent', 'abbreviation': ...
# 17  {'id': 40, 'name': 'miles', 'abbreviation': 'm...
# 18  {'id': 47, 'name': 'miles per square mile', 'a...
# 19  {'id': 36, 'name': 'inches', 'abbreviation': '...
# 20  {'id': 11, 'name': 'percent', 'abbreviation': ...
# 21  {'id': 1, 'name': 'dimensionless', 'abbreviati...
#
#                                              citation
# 0   {'id': 19, 'title': '2016, Magnitude, frequenc...
# 1   {'id': 19, 'title': '2016, Magnitude, frequenc...
# 2   {'id': 19, 'title': '2016, Magnitude, frequenc...
# 3   {'id': 19, 'title': '2016, Magnitude, frequenc...
# 4   {'id': 19, 'title': '2016, Magnitude, frequenc...
# 5   {'id': 19, 'title': '2016, Magnitude, frequenc...
# 6   {'id': 19, 'title': '2016, Magnitude, frequenc...
# 7   {'id': 19, 'title': '2016, Magnitude, frequenc...
# 8   {'id': 19, 'title': '2016, Magnitude, frequenc...
# 9   {'id': 19, 'title': '2016, Magnitude, frequenc...
# 10  {'id': 19, 'title': '2016, Magnitude, frequenc...
# 11  {'id': 19, 'title': '2016, Magnitude, frequenc...
# 12  {'id': 19, 'title': '2016, Magnitude, frequenc...
# 13  {'id': 19, 'title': '2016, Magnitude, frequenc...
# 14  {'id': 19, 'title': '2016, Magnitude, frequenc...
# 15  {'id': 19, 'title': '2016, Magnitude, frequenc...
# 16  {'id': 19, 'title': '2016, Magnitude, frequenc...
# 17  {'id': 19, 'title': '2016, Magnitude, frequenc...
# 18  {'id': 19, 'title': '2016, Magnitude, frequenc...
# 19  {'id': 19, 'title': '2016, Magnitude, frequenc...
# 20  {'id': 19, 'title': '2016, Magnitude, frequenc...
# 21  {'id': 19, 'title': '2016, Magnitude, frequenc...

# %%
precipCHECK = basinCharacteristics["parameters"][1]["code"]
PRECIP = basinCharacteristics["parameters"][1]["value"]
DRNAREA = gS["value"][gS['code'] == "DRNAREA"].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'code'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 3
#       1 precipCHECK = basinCharacteristics["parameters"][1]["code"]
#       2 PRECIP = basinCharacteristics["parameters"][1]["value"]
# ----> 3 DRNAREA = gS["value"][gS['code'] == "DRNAREA"].values
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'code'

# %%
StreamStatsServiceURLS = {
    'gage': 'https://streamstats.usgs.gov/gagestatsservices/stations/'
    }


# gageURLParams = {
#     "idOrCode": 12115700
# }


gageResponse = requests.get(url = StreamStatsServiceURLS['gage']+'12115700')

if gageResponse.status_code == 200:
    cookies = gageResponse.cookies
    try:
        gageStats = pd.DataFrame(json.loads(gageResponse.content.decode('utf-8')))


#         varCode = pd.DataFrame(list(gageStats["variableType"]))["code"]
#         units = pd.DataFrame(list(gageStats["unitType"]))["name"]

#         gS = pd.DataFrame(gageStats[["variableTypeID","value"]]).reset_index(drop=True)
#         gS["code"] = varCode
#         gS["unit"] = units
#         gS =gS.set_index('code')
    except:
        pass
    
else:
    pass

# %%
gageResponse
# Out:
# <Response [200]>

# %%
json.loads(gageResponse.content.decode('utf-8'))["region"]['id']
# Out:
# 51

# %%
gageStats
# Out:
#     id        code  agencyID  \
# 0    3  EC_05PD028         3
# 1    4  EC_05PD024         3
# 2    5  EC_05PD023         3
# 3    8  EC_05PD017         3
# 4    9  EC_05PD015         3
# 5   13  EC_05PC010         3
# 6   14  EC_05PB018         3
# 7   16  EC_05PB014         3
# 8   17    50345000         1
# 9   18    50332000         1
# 10  19    50295000         1
# 11  20    50294000         1
# 12  21    50292600         1
# 13  22    50276000         1
# 14  23    50274000         1
# 15  24    50252000         1
# 16  25    50148890         1
# 17  26    50147800         1
# 18  27    50147000         1
# 19  28    50145000         1
# 20  29    50144000         1
# 21  30    50143900         1
# 22  31    50143110         1
# 23  32    50142700         1
# 24  33    50141600         1
# 25  34    50141000         1
# 26  35    50138000         1
# 27  36    50136400         1
# 28  37    50136000         1
# 29  38    50134550         1
# 30  39    50133800         1
# 31  40    50131990         1
# 32  41    50131800         1
# 33  42    50130320         1
# 34  43    50129900         1
# 35  44    50129500         1
# 36  45    50129300         1
# 37  46    50129254         1
# 38  47    50129000         1
# 39  48    50128950         1
# 40  49    50128945         1
# 41  50    50128940         1
# 42  51    50128935         1
# 43  52    50128925         1
# 44  53    50128920         1
# 45  54    50128905         1
# 46  55    50128000         1
# 47  56    50126150         1
# 48  57    50125900         1
# 49  58    50125790         1
#
#                                                  name  isRegulated  \
# 0                         LAKE 661 OUTLET NEAR KENORA        False
# 1              LAKE 239  LOWER EAST INLET NEAR KENORA        False
# 2                         LAKE 239 OUTLET NEAR KENORA        False
# 3                         LAKE 470 OUTLET NEAR KENORA        False
# 4                         LAKE 240 OUTLET NEAR KENORA        False
# 5                         STURGEON RIVER NEAR BARWICK        False
# 6                          ATIKOKAN RIVER AT ATIKOKAN        False
# 7                       TURTLE RIVER NEAR MINE CENTRE        False
# 8        JOLLY HILL GUT AT JOLLY HILL, ST. CROIX USVI        False
# 9                  RIVER GUT AT RIVER, ST. CROIX USVI        False
# 10              GUINEA GUT AT BETHANY, ST. JOHN, USVI        False
# 11            FISH BAY GUT AT FISH BAY, ST. JOHN USVI        False
# 12   LAMESHUR BAY GUT AT LAMESHUR BAY, ST. JOHN  USVI        False
# 13       TURPENTINE RUN AT MARIENDAL, ST. THOMAS USVI        False
# 14        TURPENTINE RUN AT MT. ZION, ST. THOMAS USVI        False
# 15  BONNE RESOLUTION GUT AT BONNE RESOLUTION ST TH...        False
# 16  RIO CULEBRINAS AT MARGARITA DAMSITE NR AGUADA, PR        False
# 17              RIO CULEBRINAS AT HWY 404 NR MOCA, PR        False
# 18                RIO CULEBRINAS AT SAN SEBASTIAN, PR        False
# 19              RIO GRANDE DE ANASCO AT EL ESPINO, PR        False
# 20          RIO GRANDE DE ANASCO NR SAN SEBASTIAN, PR        False
# 21                       RIO ARENAS AT LAS MARIAS, PR        False
# 22                       RIO GUABA AT BUCARABONES, PR        False
# 23                            RIO PRIETO NR LARES, PR        False
# 24                    RIO GUAYO AT MOUTH NR LARES, PR        False
# 25                         RIO BLANCO NR ADJUNTAS, PR        False
# 26                   RIO GUANAJIBO NR HORMIGUEROS, PR        False
# 27                     RIO ROSARIO NR HORMIGUEROS, PR        False
# 28                         RIO ROSARIO AT ROSARIO, PR        False
# 29      RIO HOCONUCO AT HOCONUCO BAJO, SAN GERMAN, PR        False
# 30                            RIO DUEY NR ROSARIO, PR        False
# 31         RIO GUANAJIBO AT HWY 119 AT SAN GERMAN, PR        False
# 32                      RIO CUPEYES NR SAN GERMAN, PR        False
# 33                       QUEBRADA MAMEY AT JOYUDA, PR        False
# 34           LAGUNA CARTAGENA OUTFLOW NR BOQUERON, PR        False
# 35                            RIO LOCO NR GUANICA, PR        False
# 36          LAJAS EAST DRAINAGE CANAL NR ENSENADA, PR        False
# 37    RIO LOCO AT LAS LATAS NR LA JOYA NR GUANICA, PR        False
# 38                              RIO LOCO NR YAUCO, PR        False
# 39             LAJAS IRRIGATION CANAL NR BOQUERON, PR        False
# 40  CANAL DE RIEGO DE LAJAS AT BO. PALMAREJO NR LAJAS        False
# 41  CANAL DE RIEGO DE LAJAS BLW LAJAS FILT PLANT L...        False
# 42  CANAL DE RIEGO DE LAJAS ABV LAJAS FILT PLANT L...        False
# 43  CANAL DE RIEGO DE LAJAS BLW MAJINAS FILT. PLAN...        False
# 44  CANAL DE RIEGO DE LAJAS ABV MAJINAS FILT. PLAN...        False
# 45  CANAL DE RIEGO DE LAJAS BLW LAGO LOCO DAM YAUC...        False
# 46                             RIO YAUCO NR YAUCO, PR        False
# 47    RIO YAUCO ABV DIVERSION MONSERRATE NR YAUCO, PR        False
# 48                RIO DUEY ABV DIVERSION NR YAUCO, PR        False
# 49                 RIO YAUCO AT LUCCHETTI DAMSITE, PR        False
#
#     stationTypeID                                           location  \
# 0               1  {'type': 'Point', 'coordinates': [-93.7397, 49...
# 1               1  {'type': 'Point', 'coordinates': [-93.7133, 49...
# 2               1  {'type': 'Point', 'coordinates': [-93.7267, 49...
# 3               1  {'type': 'Point', 'coordinates': [-93.7325, 49...
# 4               1  {'type': 'Point', 'coordinates': [-93.7261, 49...
# 5               1  {'type': 'Point', 'coordinates': [-93.9833, 48...
# 6               1  {'type': 'Point', 'coordinates': [-91.5841, 48...
# 7               1  {'type': 'Point', 'coordinates': [-92.7238, 48...
# 8               1  {'type': 'Point', 'coordinates': [-64.8626461,...
# 9               1  {'type': 'Point', 'coordinates': [-64.8140344,...
# 10              1  {'type': 'Point', 'coordinates': [-64.780138, ...
# 11              1  {'type': 'Point', 'coordinates': [-64.76402639...
# 12              1  {'type': 'Point', 'coordinates': [-64.721803, ...
# 13              1  {'type': 'Point', 'coordinates': [-64.88236417...
# 14              1  {'type': 'Point', 'coordinates': [-64.8884756,...
# 15              1  {'type': 'Point', 'coordinates': [-64.95903528...
# 16              1  {'type': 'Point', 'coordinates': [-67.1507361,...
# 17              1  {'type': 'Point', 'coordinates': [-67.0921242,...
# 18              8  {'type': 'Point', 'coordinates': [-66.99573389...
# 19              1  {'type': 'Point', 'coordinates': [-67.1124019,...
# 20              1  {'type': 'Point', 'coordinates': [-67.0510122,...
# 21              8  {'type': 'Point', 'coordinates': [-66.99878917...
# 22              8  {'type': 'Point', 'coordinates': [-66.9572053,...
# 23              1  {'type': 'Point', 'coordinates': [-66.8815656,...
# 24              1  {'type': 'Point', 'coordinates': [-66.8318425,...
# 25              1  {'type': 'Point', 'coordinates': [-66.79989778...
# 26              1  {'type': 'Point', 'coordinates': [-67.1487908,...
# 27              1  {'type': 'Point', 'coordinates': [-67.0749017,...
# 28              1  {'type': 'Point', 'coordinates': [-67.0749017,...
# 29              8  {'type': 'Point', 'coordinates': [-67.0689458,...
# 30              1  {'type': 'Point', 'coordinates': [-67.0537906,...
# 31              1  {'type': 'Point', 'coordinates': [-67.0335117,...
# 32              8  {'type': 'Point', 'coordinates': [-67.00628889...
# 33              1  {'type': 'Point', 'coordinates': [-67.1687908,...
# 34              1  {'type': 'Point', 'coordinates': [-67.1090672,...
# 35              1  {'type': 'Point', 'coordinates': [-66.9160094,...
# 36              1  {'type': 'Point', 'coordinates': [-66.9729547,...
# 37              8  {'type': 'Point', 'coordinates': [-66.8763204,...
# 38              1  {'type': 'Point', 'coordinates': [-66.88795417...
# 39              1  {'type': 'Point', 'coordinates': [-67.13906778...
# 40              1  {'type': 'Point', 'coordinates': [-67.07851169...
# 41              1  {'type': 'Point', 'coordinates': [-67.0540672,...
# 42              1  {'type': 'Point', 'coordinates': [-67.054345, ...
# 43              1  {'type': 'Point', 'coordinates': [-66.94962114...
# 44              1  {'type': 'Point', 'coordinates': [-66.94906558...
# 45              1  {'type': 'Point', 'coordinates': [-66.88795417...
# 46              1  {'type': 'Point', 'coordinates': [-66.8315644,...
# 47              1  {'type': 'Point', 'coordinates': [-66.8412872,...
# 48              1  {'type': 'Point', 'coordinates': [-66.8460094,...
# 49              1  {'type': 'Point', 'coordinates': [-66.8646208,...
#
#     regionID                                        stationType
# 0         67  {'id': 1, 'name': 'Gaging Station, continuous ...
# 1         67  {'id': 1, 'name': 'Gaging Station, continuous ...
# 2         67  {'id': 1, 'name': 'Gaging Station, continuous ...
# 3         67  {'id': 1, 'name': 'Gaging Station, continuous ...
# 4         67  {'id': 1, 'name': 'Gaging Station, continuous ...
# 5         67  {'id': 1, 'name': 'Gaging Station, continuous ...
# 6         67  {'id': 1, 'name': 'Gaging Station, continuous ...
# 7         67  {'id': 1, 'name': 'Gaging Station, continuous ...
# 8         64  {'id': 1, 'name': 'Gaging Station, continuous ...
# 9         64  {'id': 1, 'name': 'Gaging Station, continuous ...
# 10        64  {'id': 1, 'name': 'Gaging Station, continuous ...
# 11        64  {'id': 1, 'name': 'Gaging Station, continuous ...
# 12        64  {'id': 1, 'name': 'Gaging Station, continuous ...
# 13        64  {'id': 1, 'name': 'Gaging Station, continuous ...
# 14        64  {'id': 1, 'name': 'Gaging Station, continuous ...
# 15        64  {'id': 1, 'name': 'Gaging Station, continuous ...
# 16        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 17        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 18        62  {'id': 8, 'name': 'Undefined', 'description': ...
# 19        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 20        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 21        62  {'id': 8, 'name': 'Undefined', 'description': ...
# 22        62  {'id': 8, 'name': 'Undefined', 'description': ...
# 23        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 24        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 25        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 26        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 27        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 28        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 29        62  {'id': 8, 'name': 'Undefined', 'description': ...
# 30        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 31        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 32        62  {'id': 8, 'name': 'Undefined', 'description': ...
# 33        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 34        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 35        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 36        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 37        62  {'id': 8, 'name': 'Undefined', 'description': ...
# 38        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 39        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 40        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 41        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 42        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 43        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 44        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 45        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 46        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 47        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 48        62  {'id': 1, 'name': 'Gaging Station, continuous ...
# 49        62  {'id': 1, 'name': 'Gaging Station, continuous ...
